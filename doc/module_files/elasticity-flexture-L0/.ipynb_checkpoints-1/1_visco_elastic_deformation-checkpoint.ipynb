# %% [markdown]
# ## Visco-elastic deformation
#
# A material is considered *elastic* if it goes back to its original shape once the applied force is removed (see figure below). Under elastic deformation, the strains are linearly proportional to the applied stresses.
#
# At shallow depths, where both temperatures and pressures are low, rocks dominantly deform elastically. The existence of lithospheric structures that are over one billion years old suggests that the Earth's lithosphere behaves elastically on geological time scales.
#
# At greater depth and under high temperature and pressure conditions, the rocks can *flow* and are better described by their viscous behavior. For Newtonian fluids, the strain rate of rocks is proportional to the applied stress.
# Several geological evidence exist that point to the viscous deformation of the Earth's mantle. Some examples include:
#
# 1. **Post glacial rebound**: uplift of the Earth's crust in response to the mantle flow underneath as the glacial load is removed
# 2. **Plate tectonics**: surface experessions such as mountains and basins form as plates move relative to each other over a convecting mantle
# 3. **Seismic anisotropy**: seismic anisotropy observed in tectonically active regions suggests mantle shearing
# 4. **Hotspot track**: Hawaiin-Emperor seamount chain formed as the Pacific plate moved over the Hawaiin mantle plume

# %% [markdown]
# <div>
# <img src='./images/plate-rebound.png' width="500"/>
# <figcaption align = "center"> Image: Deformation of the Earth lithosphere during and after a glaciation event. Image modified from Jacqueline Austermann, Columbia University</figcaption>
# </div>

# %% [markdown]
# ### Maxwell Model
#
# The Earth deforms both elastically and viscously at different time scales:
# * Elastic deformation occurs instantaneously
# * Viscous deformation increases with time
#
# <div>
# <img src='./images/maxwell-model.png' width="700"/>
# <figcaption align = "center"> Image: Based on Juliane Dannberg's course on Introduction to Geophysics, University of Florida</figcaption>
# </div>
#
# **Maxwell relaxation time**: Maxwell relaxation time is defined as the ratio of Viscosity, $\eta$, and the Shear modulus, G, and represents how long it takes for a deformed visco-elastic system to flow to a steady-state.
# \begin{equation}
#   t_{maxwell} = \frac{\eta}{G}  \approx \frac{10^{22} \text{Pa.s}} {10^{11} Pa} \approx O(10^3 yrs)
# \end{equation}
#
# <div>
# <img src='./images/visco-elastic.png' width="250"/>
# </div>
